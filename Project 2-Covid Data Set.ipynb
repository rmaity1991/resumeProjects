# %%
import pandas as pd

# %%
master_data=pd.read_csv("covid_19_india.csv")

# %%
master_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
master_data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
wb_data=master_data[master_data['State/UnionTerritory']== 'West Bengal']

# %%
wb_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 208      209  2020-03-18  6:00 PM          West Bengal
# 227      228  2020-03-19  6:00 PM          West Bengal
# 247      248  2020-03-20  6:00 PM          West Bengal
# 269      270  2020-03-21  6:00 PM          West Bengal
# 292      293  2020-03-22  6:00 PM          West Bengal
# ...      ...         ...      ...                  ...
# 17965  17966  2021-08-07  8:00 AM          West Bengal
# 18001  18002  2021-08-08  8:00 AM          West Bengal
# 18037  18038  2021-08-09  8:00 AM          West Bengal
# 18073  18074  2021-08-10  8:00 AM          West Bengal
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 208                         1                        0        0       0
# 227                         1                        0        0       0
# 247                         2                        0        0       0
# ...

# %%
wb_data[['Cured','Deaths','Confirmed']].describe()
# Out:
#               Cured        Deaths     Confirmed
# count  5.120000e+02    512.000000  5.120000e+02
# mean   4.834279e+05   7513.650391  5.138826e+05
# std    4.798799e+05   5860.845822  4.960510e+05
# min    0.000000e+00      0.000000  1.000000e+00
# 25%    3.115450e+04   1246.500000  5.114800e+04
# 50%    4.428435e+05   8296.000000  4.757165e+05
# 75%    5.732840e+05  10345.000000  5.941052e+05
# max    1.506532e+06  18252.000000  1.534999e+06

# %%
wb_data['Confirmed-Cured']=wb_data['Confirmed']-wb_data['Cured']
# Out:
# C:\Users\11037833\AppData\Local\Temp/ipykernel_12204/220561170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wb_data['Confirmed-Cured']=wb_data['Confirmed']-wb_data['Cured']

# %%
wb_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 208      209  2020-03-18  6:00 PM          West Bengal
# 227      228  2020-03-19  6:00 PM          West Bengal
# 247      248  2020-03-20  6:00 PM          West Bengal
# 269      270  2020-03-21  6:00 PM          West Bengal
# 292      293  2020-03-22  6:00 PM          West Bengal
# ...      ...         ...      ...                  ...
# 17965  17966  2021-08-07  8:00 AM          West Bengal
# 18001  18002  2021-08-08  8:00 AM          West Bengal
# 18037  18038  2021-08-09  8:00 AM          West Bengal
# 18073  18074  2021-08-10  8:00 AM          West Bengal
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 208                         1                        0        0       0
# 227                         1                        0        0       0
# 247                         2                        0        0       0
# ...

# %%
wb_data['Unaccounted']=wb_data['Confirmed-Cured']-wb_data['Deaths']
# Out:
# C:\Users\11037833\AppData\Local\Temp/ipykernel_12204/1918995029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wb_data['Unaccounted']=wb_data['Confirmed-Cured']-wb_data['Deaths']

# %%
wb_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 208      209  2020-03-18  6:00 PM          West Bengal
# 227      228  2020-03-19  6:00 PM          West Bengal
# 247      248  2020-03-20  6:00 PM          West Bengal
# 269      270  2020-03-21  6:00 PM          West Bengal
# 292      293  2020-03-22  6:00 PM          West Bengal
# ...      ...         ...      ...                  ...
# 17965  17966  2021-08-07  8:00 AM          West Bengal
# 18001  18002  2021-08-08  8:00 AM          West Bengal
# 18037  18038  2021-08-09  8:00 AM          West Bengal
# 18073  18074  2021-08-10  8:00 AM          West Bengal
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 208                         1                        0        0       0
# 227                         1                        0        0       0
# 247                         2                        0        0       0
# ...
