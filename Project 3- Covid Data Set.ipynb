# %%
import pandas as pd

# %%
covid_df = pd.read_csv('covid19_italy_region.csv')

# %%
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
covid_df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6027 entries, 0 to 6026
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SNo                        6027 non-null   int64
#  1   Date                       6027 non-null   object
#  2   Country                    6027 non-null   object
#  3   RegionCode                 6027 non-null   int64
#  4   RegionName                 6027 non-null   object
#  5   Latitude                   6027 non-null   float64
#  6   Longitude                  6027 non-null   float64
#  7   HospitalizedPatients       6027 non-null   int64
#  8   IntensiveCarePatients      6027 non-null   int64
#  9   TotalHospitalizedPatients  6027 non-null   int64
#  10  HomeConfinement            6027 non-null   int64
#  11  CurrentPositiveCases       6027 non-null   int64
#  12  NewPositiveCases           6027 non-null   int64
# ...

# %%
covid_df.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  6027.000000  6027.000000  6027.000000  6027.000000
# mean   3013.000000    11.857143    43.046293    12.225955
# std    1739.989368     6.274319     2.488987     2.659168
# min       0.000000     1.000000    38.115697     7.320149
# 25%    1506.500000     7.000000    41.125596    11.121231
# 50%    3013.000000    12.000000    43.616760    12.388247
# 75%    4519.500000    17.000000    45.434905    13.768136
# max    6026.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           6027.000000            6027.000000                6027.000000
# mean             509.093579              55.892318                 564.985897
# std             1272.731157             134.957979                1403.362341
# min                0.000000               0.000000                   0.000000
# ...

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
covid_df.shape
# Out:
# (6027, 17)

# %%
covid_df['NewPositiveCases']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4         18
#         ...
# 6022    1022
# 6023     753
# 6024     234
# 6025      34
# 6026    3444
# Name: NewPositiveCases, Length: 6027, dtype: int64

# %%
type(covid_df['NewPositiveCases'])
# Out:
# pandas.core.series.Series

# %%
covid_df['NewPositiveCases'][246]
# Out:
# 3

# %%
covid_df['NewPositiveCases'][240]
# Out:
# 35

# %%
covid_df.at[246, 'NewPositiveCases']
# Out:
# 3

# %%
covid_df.at[240, 'NewPositiveCases']
# Out:
# 35

# %%
covid_df.NewPositiveCases
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4         18
#         ...
# 6022    1022
# 6023     753
# 6024     234
# 6025      34
# 6026    3444
# Name: NewPositiveCases, Length: 6027, dtype: int64

# %%
cases_df = covid_df[['Date', 'NewPositiveCases']]
cases_df
# Out:
#                      Date  NewPositiveCases
# 0     2020-02-24T18:00:00                 0
# 1     2020-02-24T18:00:00                 0
# 2     2020-02-24T18:00:00                 0
# 3     2020-02-24T18:00:00                 0
# 4     2020-02-24T18:00:00                18
# ...                   ...               ...
# 6022  2020-12-06T17:00:00              1022
# 6023  2020-12-06T17:00:00               753
# 6024  2020-12-06T17:00:00               234
# 6025  2020-12-06T17:00:00                34
# 6026  2020-12-06T17:00:00              3444
#
# [6027 rows x 2 columns]

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
covid_df_copy = covid_df.copy()

# %%
covid_df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
covid_df.loc[243]
# Out:
# SNo                                          243
# Date                         2020-03-06T17:00:00
# Country                                      ITA
# RegionCode                                    22
# RegionName                           P.A. Trento
# Latitude                               46.068935
# Longitude                              11.121231
# HospitalizedPatients                           4
# IntensiveCarePatients                          0
# TotalHospitalizedPatients                      4
# HomeConfinement                                6
# CurrentPositiveCases                          10
# NewPositiveCases                               3
# Recovered                                      0
# Deaths                                         0
# TotalPositiveCases                            10
# TestsPerformed                               NaN
# Name: 243, dtype: object

# %%
type(covid_df.loc[243])
# Out:
# pandas.core.series.Series

# %%
covid_df.head(5)
# Out:
#    SNo                 Date Country  RegionCode      RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13         Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17      Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA          18        Calabria  38.905976
# 3    3  2020-02-24T18:00:00     ITA          15        Campania  40.839566
# 4    4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna  44.494367
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  16.594402                     0                      0
# 3  14.250850                     0                      0
# 4  11.341721                    10                      2
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
covid_df.tail(4)
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 6023  6023  2020-12-06T17:00:00     ITA           9        Toscana  43.769231
# 6024  6024  2020-12-06T17:00:00     ITA          10         Umbria  43.106758
# 6025  6025  2020-12-06T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 6026  6026  2020-12-06T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 6023  11.255889                  1360                    252
# 6024  12.388247                   332                     60
# 6025   7.320149                   102                      8
# 6026  12.338452                  2508                    308
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 6023                       1612            27587                 29199
# 6024                        392             5673                  6065
# ...

# %%
covid_df.at[0, 'TestsPerformed']
# Out:
# nan

# %%
type(covid_df.at[0, 'TestsPerformed'])
# Out:
# numpy.float64

# %%
covid_df.TestsPerformed.first_valid_index()
# Out:
# 1155

# %%
covid_df.loc[108:113]
# Out:
#      SNo                 Date Country  RegionCode             RegionName  \
# 108  108  2020-02-29T17:00:00     ITA          15               Campania
# 109  109  2020-02-29T17:00:00     ITA           8         Emilia-Romagna
# 110  110  2020-02-29T17:00:00     ITA           6  Friuli Venezia Giulia
# 111  111  2020-02-29T17:00:00     ITA          12                  Lazio
# 112  112  2020-02-29T17:00:00     ITA           7                Liguria
# 113  113  2020-02-29T17:00:00     ITA           3              Lombardia
#
#       Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 108  40.839566  14.250850                     3                      0
# 109  44.494367  11.341721                    86                     11
# 110  45.649435  13.768136                     0                      0
# 111  41.892770  12.483667                     3                      0
# 112  44.411493   8.932699                     4                      1
# ...

# %%
covid_df.sample(10)
# Out:
#        SNo                 Date Country  RegionCode             RegionName  \
# 2343  2343  2020-06-14T17:00:00     ITA          22            P.A. Trento
# 3633  3633  2020-08-15T17:00:00     ITA          13                Abruzzo
# 500    500  2020-03-18T17:00:00     ITA           9                Toscana
# 4850  4850  2020-10-11T17:00:00     ITA           5                 Veneto
# 1552  1552  2020-05-07T17:00:00     ITA           2          Valle d'Aosta
# 2666  2666  2020-06-29T17:00:00     ITA           5                 Veneto
# 4941  4941  2020-10-16T17:00:00     ITA          12                  Lazio
# 4520  4520  2020-09-26T17:00:00     ITA           6  Friuli Venezia Giulia
# 1983  1983  2020-05-28T17:00:00     ITA          11                 Marche
# 2298  2298  2020-06-12T17:00:00     ITA          11                 Marche
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# ...

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
total_cases = covid_df.CurrentPositiveCases.sum()
total_deaths = covid_df.Deaths.sum()

# %%
print('The number of reported cases is {} and the number of reported deaths is {}.'.format(int(total_cases), int(total_deaths)))
# Out:
# The number of reported cases is 37897157 and the number of reported deaths is 8886032.

# %%
death_rate = covid_df.Deaths.sum() / covid_df.CurrentPositiveCases.sum()

# %%
print("The overall reported death rate in Italy is {:.2f} %.".format(death_rate*100))
# Out:
# The overall reported death rate in Italy is 23.45 %.

# %%
initial_tests = 935310
total_tests = initial_tests + covid_df.TestsPerformed.sum()

# %%
total_tests
# Out:
# 1268050100.0

# %%
positive_rate = total_cases / total_tests

# %%
print('{:.2f}% of tests in Italy led to a positive diagnosis.'.format(positive_rate*100))
# Out:
# 2.99% of tests in Italy led to a positive diagnosis.

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
high_new_cases = covid_df.NewPositiveCases > 1000

# %%
high_new_cases
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6022     True
# 6023    False
# 6024    False
# 6025    False
# 6026     True
# Name: NewPositiveCases, Length: 6027, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#        SNo                 Date Country  RegionCode RegionName   Latitude  \
# 302    302  2020-03-09T18:00:00     ITA           3  Lombardia  45.466794
# 344    344  2020-03-11T17:00:00     ITA           3  Lombardia  45.466794
# 365    365  2020-03-12T17:00:00     ITA           3  Lombardia  45.466794
# 386    386  2020-03-13T17:00:00     ITA           3  Lombardia  45.466794
# 407    407  2020-03-14T17:00:00     ITA           3  Lombardia  45.466794
# ...    ...                  ...     ...         ...        ...        ...
# 6014  6014  2020-12-06T17:00:00     ITA           3  Lombardia  45.466794
# 6019  6019  2020-12-06T17:00:00     ITA           1   Piemonte  45.073274
# 6020  6020  2020-12-06T17:00:00     ITA          16     Puglia  41.125596
# 6022  6022  2020-12-06T17:00:00     ITA          19    Sicilia  38.115697
# 6026  6026  2020-12-06T17:00:00     ITA           5     Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# ...

# %%
high_cases_df = covid_df[covid_df.NewPositiveCases > 1000]

# %%
high_cases_df
# Out:
#        SNo                 Date Country  RegionCode RegionName   Latitude  \
# 302    302  2020-03-09T18:00:00     ITA           3  Lombardia  45.466794
# 344    344  2020-03-11T17:00:00     ITA           3  Lombardia  45.466794
# 365    365  2020-03-12T17:00:00     ITA           3  Lombardia  45.466794
# 386    386  2020-03-13T17:00:00     ITA           3  Lombardia  45.466794
# 407    407  2020-03-14T17:00:00     ITA           3  Lombardia  45.466794
# ...    ...                  ...     ...         ...        ...        ...
# 6014  6014  2020-12-06T17:00:00     ITA           3  Lombardia  45.466794
# 6019  6019  2020-12-06T17:00:00     ITA           1   Piemonte  45.073274
# 6020  6020  2020-12-06T17:00:00     ITA          16     Puglia  41.125596
# 6022  6022  2020-12-06T17:00:00     ITA          19    Sicilia  38.115697
# 6026  6026  2020-12-06T17:00:00     ITA           5     Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# ...

# %%
positive_rate
# Out:
# 0.029886166958229803

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
high_ratio_df = covid_df[covid_df.CurrentPositiveCases / covid_df.TestsPerformed > positive_rate]

# %%
high_ratio_df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 1155  1155  2020-04-19T17:00:00     ITA          13         Abruzzo
# 1156  1156  2020-04-19T17:00:00     ITA          17      Basilicata
# 1157  1157  2020-04-19T17:00:00     ITA          18        Calabria
# 1158  1158  2020-04-19T17:00:00     ITA          15        Campania
# 1159  1159  2020-04-19T17:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6019  6019  2020-12-06T17:00:00     ITA           1        Piemonte
# 6020  6020  2020-12-06T17:00:00     ITA          16          Puglia
# 6021  6021  2020-12-06T17:00:00     ITA          20        Sardegna
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 1155  42.351222  13.398438                   317                     40
# ...

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
covid_df.NewPositiveCases / covid_df.TestsPerformed
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 6022    0.001477
# 6023    0.000766
# 6024    0.001011
# 6025    0.000981
# 6026    0.003157
# Length: 6027, dtype: float64

# %%
covid_df['positive_rate'] = covid_df.NewPositiveCases / covid_df.TestsPerformed

# %%
covid_df
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 6022  6022  2020-12-06T17:00:00     ITA          19         Sicilia
# 6023  6023  2020-12-06T17:00:00     ITA           9         Toscana
# 6024  6024  2020-12-06T17:00:00     ITA          10          Umbria
# 6025  6025  2020-12-06T17:00:00     ITA           2   Valle d'Aosta
# 6026  6026  2020-12-06T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
covid_df.drop(columns=['positive_rate'], inplace=True)

# %%
covid_df.sort_values('NewPositiveCases', ascending=False).head(10)
# Out:
#        SNo                 Date Country  RegionCode RegionName   Latitude  \
# 5405  5405  2020-11-07T17:00:00     ITA           3  Lombardia  45.466794
# 5468  5468  2020-11-10T17:00:00     ITA           3  Lombardia  45.466794
# 5531  5531  2020-11-13T17:00:00     ITA           3  Lombardia  45.466794
# 5384  5384  2020-11-06T17:00:00     ITA           3  Lombardia  45.466794
# 5510  5510  2020-11-12T17:00:00     ITA           3  Lombardia  45.466794
# 5678  5678  2020-11-20T17:00:00     ITA           3  Lombardia  45.466794
# 5237  5237  2020-10-30T17:00:00     ITA           3  Lombardia  45.466794
# 5258  5258  2020-10-31T17:00:00     ITA           3  Lombardia  45.466794
# 5699  5699  2020-11-21T17:00:00     ITA           3  Lombardia  45.466794
# 5363  5363  2020-11-05T17:00:00     ITA           3  Lombardia  45.466794
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 5405   9.190347                  5813                    610
# ...

# %%
covid_df.sort_values('Deaths', ascending=False).head(10)
# Out:
#        SNo                 Date Country  RegionCode RegionName   Latitude  \
# 6014  6014  2020-12-06T17:00:00     ITA           3  Lombardia  45.466794
# 5993  5993  2020-12-05T17:00:00     ITA           3  Lombardia  45.466794
# 5972  5972  2020-12-04T17:00:00     ITA           3  Lombardia  45.466794
# 5951  5951  2020-12-03T17:00:00     ITA           3  Lombardia  45.466794
# 5930  5930  2020-12-02T17:00:00     ITA           3  Lombardia  45.466794
# 5909  5909  2020-12-01T17:00:00     ITA           3  Lombardia  45.466794
# 5888  5888  2020-11-30T17:00:00     ITA           3  Lombardia  45.466794
# 5867  5867  2020-11-29T17:00:00     ITA           3  Lombardia  45.466794
# 5846  5846  2020-11-28T17:00:00     ITA           3  Lombardia  45.466794
# 5825  5825  2020-11-27T17:00:00     ITA           3  Lombardia  45.466794
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 6014   9.190347                  6372                    807
# ...

# %%
covid_df.sort_values('NewPositiveCases').head(10)
# Out:
#        SNo                 Date Country  RegionCode  RegionName   Latitude  \
# 2292  2292  2020-06-12T17:00:00     ITA          15    Campania  40.839566
# 1115  1115  2020-04-17T17:00:00     ITA          18    Calabria  38.905976
# 133    133  2020-03-01T17:00:00     ITA           7     Liguria  44.411493
# 1534  1534  2020-05-07T17:00:00     ITA          17  Basilicata  40.639471
# 307    307  2020-03-09T18:00:00     ITA           1    Piemonte  45.073274
# 1794  1794  2020-05-19T17:00:00     ITA          11      Marche  43.616760
# 154    154  2020-03-02T18:00:00     ITA           7     Liguria  44.411493
# 163    163  2020-03-02T18:00:00     ITA          19     Sicilia  38.115697
# 1926  1926  2020-05-25T17:00:00     ITA          20    Sardegna  39.215312
# 1485  1485  2020-05-04T17:00:00     ITA          20    Sardegna  39.215312
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 2292  14.250850                    61                      2
# ...

# %%
covid_df.loc[169:175]
# Out:
#      SNo                 Date Country  RegionCode             RegionName  \
# 169  169  2020-03-03T18:00:00     ITA          17             Basilicata
# 170  170  2020-03-03T18:00:00     ITA          18               Calabria
# 171  171  2020-03-03T18:00:00     ITA          15               Campania
# 172  172  2020-03-03T18:00:00     ITA           8         Emilia-Romagna
# 173  173  2020-03-03T18:00:00     ITA           6  Friuli Venezia Giulia
# 174  174  2020-03-03T18:00:00     ITA          12                  Lazio
# 175  175  2020-03-03T18:00:00     ITA           7                Liguria
#
#       Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 169  40.639471  15.805148                     0                      0
# 170  38.905976  16.594402                     0                      0
# 171  40.839566  14.250850                    11                      0
# 172  44.494367  11.341721                   187                     24
# ...

# %%
covid_df.at[172, 'NewPositiveCases'] = (covid_df.at[171, 'NewPositiveCases'] + covid_df.at[173, 'NewPositiveCases'])/2

# %%
covid_df.Date
# Out:
# 0       2020-02-24T18:00:00
# 1       2020-02-24T18:00:00
# 2       2020-02-24T18:00:00
# 3       2020-02-24T18:00:00
# 4       2020-02-24T18:00:00
#                ...
# 6022    2020-12-06T17:00:00
# 6023    2020-12-06T17:00:00
# 6024    2020-12-06T17:00:00
# 6025    2020-12-06T17:00:00
# 6026    2020-12-06T17:00:00
# Name: Date, Length: 6027, dtype: object

# %%
covid_df['Date'] = pd.to_datetime(covid_df.Date)

# %%
covid_df['Date']
# Out:
# 0      2020-02-24 18:00:00
# 1      2020-02-24 18:00:00
# 2      2020-02-24 18:00:00
# 3      2020-02-24 18:00:00
# 4      2020-02-24 18:00:00
#                ...
# 6022   2020-12-06 17:00:00
# 6023   2020-12-06 17:00:00
# 6024   2020-12-06 17:00:00
# 6025   2020-12-06 17:00:00
# 6026   2020-12-06 17:00:00
# Name: Date, Length: 6027, dtype: datetime64[ns]

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.Date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.Date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.Date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.Date).weekday

# %%
covid_df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00     ITA          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00     ITA          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00     ITA          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00     ITA          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00     ITA           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00     ITA          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00     ITA           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00     ITA          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00     ITA           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00     ITA           5          Veneto  45.434905
#
# ...

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed', 'year', 'month', 'day', 'weekday'],
#       dtype='object')

# %%
# Query the rows for May
covid_df_may = covid_df[covid_df.month == 5]

# Extract the subset of columns to be aggregated
covid_df_may_metrics = covid_df_may[['NewPositiveCases', 'Deaths', 'TestsPerformed']]

# Get the column-wise sum
covid_may_totals = covid_df_may_metrics.sum()

# %%
covid_may_totals
# Out:
# NewPositiveCases       27556.0
# Deaths                973585.0
# TestsPerformed      58918148.0
# dtype: float64

# %%
type(covid_may_totals)
# Out:
# pandas.core.series.Series

# %%
covid_df[covid_df.month == 5][['NewPositiveCases', 'Deaths', 'TestsPerformed']].sum()
# Out:
# NewPositiveCases       27556.0
# Deaths                973585.0
# TestsPerformed      58918148.0
# dtype: float64

# %%
# Overall average
covid_df.NewPositiveCases.mean()
# Out:
# 286.8730711796914

# %%
# Average for Sundays
covid_df[covid_df.weekday == 6].NewPositiveCases.mean()
# Out:
# 291.56678281068525

# %%
covid_month_df = covid_df.groupby('month')[['NewPositiveCases', 'Deaths', 'TestsPerformed']].sum()

# %%
covid_month_df
# Out:
#        NewPositiveCases   Deaths  TestsPerformed
# month
# 2                  1120       96             0.0
# 3                104587   116566             0.0
# 4                 99671   644171      13643342.0
# 5                 27556   973585      58918148.0
# 6                  7584  1028841      86135311.0
# 7                  7006  1084927     113693227.0
# 8                 21702  1095146     140356556.0
# 9                 45623  1069879     181469958.0
# 10               364607  1137835     250655965.0
# 11               922206  1385098     342444409.0
# 12               127322   349888      79797874.0

# %%
covid_month_mean_df = covid_df.groupby('month')[['NewPositiveCases', 'Deaths', 'TestsPerformed']].mean()

# %%
covid_month_mean_df
# Out:
#        NewPositiveCases       Deaths  TestsPerformed
# month
# 2              8.888889     0.761905             NaN
# 3            160.655914   179.056836             NaN
# 4            158.207937  1022.493651    54140.246032
# 5             42.328725  1495.522273    90504.067588
# 6             12.038095  1633.080952   136722.715873
# 7             10.761905  1666.554531   174643.973886
# 8             33.336406  1682.251920   215601.468510
# 9             72.417460  1698.220635   288047.552381
# 10           560.072197  1747.826421   385032.204301
# 11          1463.819048  2198.568254   543562.553968
# 12          1010.492063  2776.888889   633316.460317

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed', 'year', 'month', 'day', 'weekday'],
#       dtype='object')

# %%
covid_df['total_cases'] = covid_df.TestsPerformed.cumsum()

# %%
covid_df['total_deaths'] = covid_df.Deaths.cumsum()

# %%
covid_df['total_tests'] = covid_df.TestsPerformed.cumsum() + initial_tests

# %%
covid_df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00     ITA          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00     ITA          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00     ITA          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00     ITA          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00     ITA           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00     ITA          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00     ITA           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00     ITA          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00     ITA           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00     ITA           5          Veneto  45.434905
#
# ...

# %%
locations_df = pd.read_csv('locations.csv')

# %%
locations_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
locations_df[locations_df.location == "Italy"]
# Out:
#    location continent  population  life_expectancy  \
# 97    Italy    Europe  60461828.0            83.51
#
#     hospital_beds_per_thousand  gdp_per_capita
# 97                        3.18       35220.084

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed', 'year', 'month', 'day', 'weekday', 'total_cases',
#        'total_deaths', 'total_tests', 'location'],
#       dtype='object')

# %%
covid_df['location'] = "Italy"

# %%
covid_df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00     ITA          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00     ITA          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00     ITA          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00     ITA          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00     ITA           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00     ITA          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00     ITA           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00     ITA          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00     ITA           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00     ITA           5          Veneto  45.434905
#
# ...

# %%
merged_df = covid_df.merge(locations_df, on="location")

# %%
merged_df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00     ITA          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00     ITA          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00     ITA          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00     ITA          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00     ITA           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00     ITA          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00     ITA           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00     ITA          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00     ITA           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00     ITA           5          Veneto  45.434905
#
# ...

# %%
merged_df['cases_per_million'] = merged_df.total_cases * 1e6 / merged_df.population

# %%
merged_df['deaths_per_million'] = merged_df.total_deaths * 1e6 / merged_df.population

# %%
merged_df['tests_per_million'] = merged_df.total_tests * 1e6 / merged_df.population

# %%
merged_df
# Out:
#        SNo                Date Country  RegionCode      RegionName   Latitude  \
# 0        0 2020-02-24 18:00:00     ITA          13         Abruzzo  42.351222
# 1        1 2020-02-24 18:00:00     ITA          17      Basilicata  40.639471
# 2        2 2020-02-24 18:00:00     ITA          18        Calabria  38.905976
# 3        3 2020-02-24 18:00:00     ITA          15        Campania  40.839566
# 4        4 2020-02-24 18:00:00     ITA           8  Emilia-Romagna  44.494367
# ...    ...                 ...     ...         ...             ...        ...
# 6022  6022 2020-12-06 17:00:00     ITA          19         Sicilia  38.115697
# 6023  6023 2020-12-06 17:00:00     ITA           9         Toscana  43.769231
# 6024  6024 2020-12-06 17:00:00     ITA          10          Umbria  43.106758
# 6025  6025 2020-12-06 17:00:00     ITA           2   Valle d'Aosta  45.737503
# 6026  6026 2020-12-06 17:00:00     ITA           5          Veneto  45.434905
#
# ...
